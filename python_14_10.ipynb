# %% [markdown]
# <a href="https://colab.research.google.com/github/Shrajal-sahu-13/python-assignment/blob/main/python_14_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# fact =sum

# %%
for num in range(100, 1000):
    temp = num
    a = num // 100
    b = (num // 10) % 10
    c = num % 10
    fact1 = 1
    fact2 = 1
    fact3 = 1
    sum = 0

    for i in range(1, a + 1):
        fact1 = fact1 * i

    for i in range(1, b + 1):
        fact2 = fact2 * i

    for i in range(1, c + 1):
        fact3 = fact3 * i

    sum = fact1 + fact2 + fact3
    if sum == temp:
        print(num)
# Out:
# 145

# %%
for num in range(1000, 10000):
    temp = num
    a = num // 1000
    b = (num // 100) % 10
    c = (num // 10) % 10
    d = num % 10
    even = 0
    odd = 0
    for val in (a, b, c, d):
        if val % 2 == 0:
            even += val
        else:
            odd += val
    print(f"Number: {num}, Even sum: {even}, Odd sum: {odd}")
# Out:
# Number: 1000, Even sum: 0, Odd sum: 1
# Number: 1001, Even sum: 0, Odd sum: 2
# Number: 1002, Even sum: 2, Odd sum: 1
# Number: 1003, Even sum: 0, Odd sum: 4
# Number: 1004, Even sum: 4, Odd sum: 1
# Number: 1005, Even sum: 0, Odd sum: 6
# Number: 1006, Even sum: 6, Odd sum: 1
# Number: 1007, Even sum: 0, Odd sum: 8
# Number: 1008, Even sum: 8, Odd sum: 1
# Number: 1009, Even sum: 0, Odd sum: 10
# Number: 1010, Even sum: 0, Odd sum: 2
# Number: 1011, Even sum: 0, Odd sum: 3
# Number: 1012, Even sum: 2, Odd sum: 2
# Number: 1013, Even sum: 0, Odd sum: 5
# Number: 1014, Even sum: 4, Odd sum: 2
# Number: 1015, Even sum: 0, Odd sum: 7
# Number: 1016, Even sum: 6, Odd sum: 2
# Number: 1017, Even sum: 0, Odd sum: 9
# Number: 1018, Even sum: 8, Odd sum: 2
# Number: 1019, Even sum: 0, Odd sum: 11
# Number: 1020, Even sum: 2, Odd sum: 1
# Number: 1021, Even sum: 2, Odd sum: 2
# Number: 1022, Even sum: 4, Odd sum: 1
# Number: 1023, Even sum: 2, Odd sum: 4
# ...

# %%
num = 12345
odd_sum = 0
even_sum = 0
p = 1
while num>0:
  t = num % 10
  if (p % 2 == 1):
   odd_sum = t + odd_sum
  else:
    even_sum = t + even_sum
    num = num // 10
    p = p + 1
    print(even_sum)
    print(odd_sum)
